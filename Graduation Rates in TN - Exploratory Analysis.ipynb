# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('white')
sns.despine()
sns.set(font_scale=1)
plt.subplots_adjust(hspace=0.5)
plt.tight_layout()

# %%
data = pd.read_csv('./data/grad_demo_fin.csv')

# %%
data
# Out:
#      grad_rate  TOTAL  ECONOMICALLY_DISADVANTAGED  H_Female  AA_FEMALE  \
# 0         0.96   1075                    0.247442  0.008372   0.002791
# 1         0.95   1120                    0.339286  0.010714   0.020536
# 2         0.92   1406                    0.199858  0.044097   0.070413
# 3         0.98    481                    0.193347  0.037422   0.016632
# 4         0.91    534                    0.237828  0.056180   0.020599
# ..         ...    ...                         ...       ...        ...
# 284       0.97   1935                    0.109044  0.027390   0.050646
# 285       0.94     75                    0.120000  0.026667   0.013333
# 286       0.11    173                    0.531792  0.028902   0.520231
# 287       0.80    520                    0.682692  0.005769   0.482692
# 288       0.60    461                    0.709328  0.008677   0.483731
#
#      W_FEMALE   AA_MALE    W_MALE    H_MALE        AA         H         W  \
# 0    0.465116  0.007442  0.500465  0.001860  0.010233  0.010233  0.965581
# 1    0.409821  0.019643  0.505357  0.016071  0.040179  0.026786  0.915179
# 2    0.351351  0.085349  0.346373  0.046942  0.155761  0.091038  0.697724
# 3    0.382536  0.027027  0.482328  0.037422  0.043659  0.074844  0.864865
# 4    0.408240  0.022472  0.423221  0.059925  0.043071  0.116105  0.831461
# ..        ...       ...       ...       ...       ...       ...       ...
# 284  0.375711  0.047028  0.430491  0.033592  0.097674  0.060982  0.806202
# 285  0.600000  0.013333  0.293333  0.013333  0.026667  0.040000  0.893333
# 286  0.005780  0.421965  0.005780  0.017341  0.942197  0.046243  0.011561
# 287  0.000000  0.492308  0.005769  0.005769  0.975000  0.011538  0.005769
# 288  0.000000  0.483731  0.002169  0.015184  0.967462  0.023861  0.002169
#
#      Expend_per_pupil
# 0             9171.37
# 1             9523.76
# 2            12546.31
# 3             9106.97
# 4             8279.85
# ..                ...
# 284           7995.72
# 285          20049.13
# 286           8876.53
# 287           9794.46
# 288          10769.02
#
# [289 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   grad_rate                   289 non-null    float64
#  1   TOTAL                       289 non-null    int64
#  2   ECONOMICALLY_DISADVANTAGED  289 non-null    float64
#  3   H_Female                    289 non-null    float64
#  4   AA_FEMALE                   289 non-null    float64
#  5   W_FEMALE                    289 non-null    float64
#  6   AA_MALE                     289 non-null    float64
#  7   W_MALE                      289 non-null    float64
#  8   H_MALE                      289 non-null    float64
#  9   AA                          289 non-null    float64
#  10  H                           289 non-null    float64
#  11  W                           289 non-null    float64
#  12  Expend_per_pupil            289 non-null    float64
# dtypes: float64(12), int64(1)
# memory usage: 29.5 KB

# %%
data.describe()
# Out:
#         grad_rate        TOTAL  ECONOMICALLY_DISADVANTAGED    H_Female  \
# count  289.000000   289.000000                  289.000000  289.000000
# mean     0.907163   864.366782                    0.302398    0.031569
# std      0.105387   542.566929                    0.145477    0.028210
# min      0.110000    13.000000                    0.007798    0.000000
# 25%      0.900000   461.000000                    0.210089    0.012210
# 50%      0.930000   747.000000                    0.286058    0.022727
# 75%      0.960000  1185.000000                    0.378151    0.043053
# max      0.990000  2295.000000                    0.730185    0.145646
#
#         AA_FEMALE    W_FEMALE     AA_MALE      W_MALE      H_MALE          AA  \
# count  289.000000  289.000000  289.000000  289.000000  289.000000  289.000000
# mean     0.100197    0.342527    0.099433    0.371526    0.034588    0.199630
# std      0.138183    0.146835    0.132523    0.155048    0.030763    0.268444
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.010903    0.279941    0.013133    0.306687    0.012963    0.024370
# 50%      0.032407    0.394516    0.034054    0.424594    0.024155    0.066587
# 75%      0.120603    0.444254    0.124088    0.476548    0.042977    0.244997
# max      0.520231    0.675676    0.492308    0.769231    0.151652    0.985816
#
#                 H           W  Expend_per_pupil
# count  289.000000  289.000000        289.000000
# mean     0.066157    0.714053      10067.354325
# std      0.057775    0.290561       3681.256404
# min      0.000000    0.001488       3684.620000
# 25%      0.026270    0.612449       8442.580000
# 50%      0.046243    0.833333       9229.970000
# 75%      0.085546    0.923529      10603.430000
# max      0.297297    0.990132      39520.570000

# %%
figure, axes = plt.subplots(3,5, figsize=(30,13))

for ax, feature in zip(axes.flat, data.columns):
    ax.grid(axis='y', color='black',alpha=.3)
    g = sns.histplot(data[feature],ax=ax, bins=30, kde=True, color='purple', line_kws={'linestyle': '--','lw':2},
                    label='Mean: ' + str(round(data[feature].mean(), 3)))
    ax.legend(loc='best')
    g.set(ylabel=None)

# %% [markdown]
# #### Observations
#
# According to a Tennesee government website, these were the demographic breakdowns in 2019 for the entire state:
# <br>
# White: 73.6%
# <br>
# AA: 16.6%
# <br>
# Hispanic:5.51%
# <br>
# These data that I have collected closely resemble the demopgraphic breakdown of the state.

# %%
def create_regplots(y_feature):
    r_label = data.corr().loc[y_feature].sort_values(ascending=False)[1:].values 
    top_correlated = data.corr().loc[y_feature].sort_values(ascending=False).index[1:]
    
    figure, axes = plt.subplots(3,5, figsize=(25,13))
    
    for ax, x_feature,r_coef in zip(axes.flat, top_correlated,r_label):
        #ax.grid(axis='y', color='black',alpha=.3)
        #ax.grid(False, axis='x')
        g = sns.regplot(data=data,x=x_feature,y=y_feature,ax=ax,
                        line_kws={'color': 'cyan'}, color='purple',
                        label = 'r^2:  ' + str(round((r_coef*r_coef), 2)))
        ax.legend(loc='best')

# %%
create_regplots('grad_rate')
# Out:
# c:\python38\lib\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %% [markdown]
# #### Observations
# An interesting trend here is that the more a school spends per pupil, the lower the graduation rate seems to be. This seems to be counter intuitive, but it would make sense if a struggling school receives more funds in hopes up driving up the graduation rate. Another noteable observation is that the higher proportion a school has of African Americans and Economically disadvantaged individuals, the lower the graduation rate seems to be. This could closely tie in with being economically disadvantaged. Let's see if that is the case.

# %%
create_regplots('ECONOMICALLY_DISADVANTAGED')
# Out:
# c:\python38\lib\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %% [markdown]
# #### Obervations
# It seems like the higher proportion of AA, the higher proportion of economically distressed students. This could explain the lower graduation  rates.

# %%
create_regplots('Expend_per_pupil')
# Out:
# c:\python38\lib\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %% [markdown]
# #### Obervations
# There is an attempt to funnel more money into distressed schools and allocate away from high performing schools. Funneling more money into schools does not seem to increase graduation rates.

# %%
create_regplots('TOTAL')
# Out:
# c:\python38\lib\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %% [markdown]
# #### Observations
# The total number of students doesn't seem to have a strong correlation with any of the features.
