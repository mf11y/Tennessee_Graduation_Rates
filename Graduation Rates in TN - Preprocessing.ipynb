# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('./Data/grad_demo_fin.csv')

# %%
data
# Out:
#      grad_rate  ECONOMICALLY_DISADVANTAGED  H_Female  AA_FEMALE  W_FEMALE  \
# 0         0.96                    0.247442  0.008372   0.002791  0.465116
# 1         0.95                    0.339286  0.010714   0.020536  0.409821
# 2         0.92                    0.199858  0.044097   0.070413  0.351351
# 3         0.98                    0.193347  0.037422   0.016632  0.382536
# 4         0.89                    0.371846  0.169323   0.086321  0.228420
# ..         ...                         ...       ...        ...       ...
# 262       0.94                    0.247493  0.058575   0.078100  0.335620
# 263       0.97                    0.071171  0.018018   0.044595  0.407207
# 264       0.96                    0.185639  0.005254   0.021016  0.432574
# 265       0.97                    0.109044  0.027390   0.050646  0.375711
# 266       0.94                    0.120000  0.026667   0.013333  0.600000
#
#       AA_MALE    W_MALE    H_MALE        AA         H         W  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   grad_rate                   267 non-null    float64
#  1   ECONOMICALLY_DISADVANTAGED  267 non-null    float64
#  2   H_Female                    267 non-null    float64
#  3   AA_FEMALE                   267 non-null    float64
#  4   W_FEMALE                    267 non-null    float64
#  5   AA_MALE                     267 non-null    float64
#  6   W_MALE                      267 non-null    float64
#  7   H_MALE                      267 non-null    float64
#  8   AA                          267 non-null    float64
#  9   H                           267 non-null    float64
#  10  W                           267 non-null    float64
#  11  Expend_per_pupil            267 non-null    float64
# dtypes: float64(12)
# memory usage: 25.2 KB

# %%
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(data.drop(columns=['grad_rate']))
scaled_data = pd.DataFrame(scaled_data, columns=data.drop(columns=['grad_rate']).columns)
scaled_data = pd.concat([scaled_data,data[['grad_rate']]], axis=1)

# %%
scaled_data.to_csv('./Data/scaled_grad_demo_fin.csv', index=False)
